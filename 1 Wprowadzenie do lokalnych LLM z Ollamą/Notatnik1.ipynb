# %% [markdown]
# # Wprowadzenie do lokalnych LLM z Ollamą​ 🦙

# %% [markdown]
# # 🦙 Notatnik 1 — Poznaj Ollama (bez kodowania)
#
# W tym notatniku **nie piszemy kodu**. Całość wykonujesz w terminalu lub przez interfejs webowy Ollamy.
# Wyniki wklejasz do komórek tekstowych poniżej.
#
# ---
# ## ⚙️ Zanim zaczniesz
#
# Upewnij się, że pobrałeś/aś Ollamę :
# Aby to zrobić mozesz wpisać w konsoli:
#
# ```bash
# ollama
# ```
#
#
# Sprawdź listę pobranych modeli:
#
# ```bash
# ollama list
# ```
#
# > 💡 **Mozesz również sprawdzić czy ollama działa poprzez przeglądarkę http://localhost:11434`.

# %% [markdown]
# ---
# ## 🟢 Zadanie 1 — Pierwsze zdanie do modelu
#
# Włącz Aplikację Ollamy lub uruchom Ollama w terminalu komendą:
#
# ```bash
# ollama run gemma4:e4b
# ```
#
# Wpisz dokładnie to zdanie:
#
# ```
# Powiedz historie o programiście.
# ```
#
# **➡️ Co obserwujesz?** Czy model "pisze" po jednym tokenie? Czy robi przerwy?
#
# Następnie zapytaj:
# ```
# Powiedz inną historię, krótszą, max 8 zdań.
# ```
#
# > 🎯 **Cel:** Zobaczyć, że model reaguje na dodatkowe instrukcje — długość, styl.

# %% [markdown]
# ### ✏️ Twoja odpowiedź — wklej wynik tutaj:
#
# ```
# (wklej odpowiedź modelu)
# ```

# %% [markdown]
# ---
# ## 🟡 Zadanie 2 — Prompt ma znaczenie
#
# Wyślij najpierw ogólny prompt:
#
# ```
# Napisz maila do nauczyciela o przedłużenie terminu projektu.
# ```
#
# Następnie wyślij bardziej szczegółowy:
#
# ```
# Napisz formalnego maila do nauczyciela z prośbą o przedłużenie terminu projektu o 3 dni.
# Jesteś studentem informatyki. Maksymalnie 5 zdań.
# ```
#
# > 🎯 **Cel:** Zobaczyć różnicę między ogólnym a precyzyjnym promptem.

# %% [markdown]
# ### ✏️ Odpowiedź na prompt ogólny:
#
# ```
# (wklej)
# ```
#
# ### ✏️ Odpowiedź na prompt szczegółowy:
#
# ```
# (wklej)
# ```
#
# **Co się zmieniło między odpowiedziami?**
#
# > *(napisz tutaj)*

# %% [markdown]
# ---
# ## 🔵 Zadanie 3 — Kontroluj format odpowiedzi
#
# Wyślij:
#
# ```
# Wyjaśnij czym jest Docker.
# ```
#
# Następnie:
#
# ```
# Wyjaśnij Docker:
# - w 3 punktach
# - prostym językiem
# - z analogią do kontenerów transportowych
# ```
#
# > 🎯 **Cel:** Kontrola nad strukturą i poziomem trudności odpowiedzi.

# %% [markdown]
# ### ✏️ Wklej odpowiedź na wersję z punktami:
#
# ```
# (wklej)
# ```

# %% [markdown]
# ---
# ## 🔴 Zadanie 4 — AI też się myli!
#
# Zadaj modelowi podchwytliwe pytanie:
#
# ```
# Ile razy litera 'r' występuje w słowie 'strawberry'?
# ```
#
# Poprawna odpowiedź to **3** (st**r**awbe**rr**y).
#
# Następnie zapytaj o coś faktograficznego:
#
# ```
# Kto był prezydentem Polski w 1990 roku?
# ```
#
# > 🎯 **Cel:** LLM nie "rozumie" — przetwarza tokeny. Zawsze weryfikuj wyniki!

# %% [markdown]
# ### ✏️ Co odpowiedział model na pytanie o 'strawberry'?
#
# ```
# (wklej)
# ```
#
# **Czy się mylił? Tak / Nie**

# %% [markdown]
# ---
# ## 🟣 Zadanie 5 — Rola systemowa (mini roleplay)
#
# Wpisz:
#
# ```
# Jesteś doświadczonym rekruterem IT. Zadaj mi 3 pytania rekrutacyjne na stanowisko junior Python developer.
# ```
#
# Odpowiedz na jedno pytanie (możesz odpowiedzieć źle), a potem wpisz:
#
# ```
# Oceń moją odpowiedź i powiedz co powinienem poprawić.
# ```
#
# > 🎯 **Cel:** Model jako "rozmówca" z konkretną rolą.

# %% [markdown]
# ### ✏️ Trzy pytania od rekrutera:
#
# ```
# (wklej)
# ```
#
# ### ✏️ Ocena Twojej odpowiedzi:
#
# ```
# (wklej)
# ```

# %% [markdown]
# ---
# ## ⭐ Zadanie 6 — Wygeneruj tekst i zapisz do pliku
#
# To zadanie **łączy Ollama z terminalem**. Poproś model o tekst:
#
# ```
# Napisz krótki artykuł (~500 słów) o tym czym są duże modele językowe (LLM).
# Pisz prostym językiem, jakbyś tłumaczył osobie bez wiedzy technicznej.
# ```
#
# Następnie zapisz odpowiedź do pliku artykul_llm.txt, który znajduje się w tym folderze
#
#
# > 💡 **Ten plik przyda Ci się w drugim notatniku!** Upewnij się, że go masz.

# %% [markdown]
# ### ✏️ Wklej wygenerowany artykuł tutaj (podgląd):
#
# ```
# (wklej pierwsze kilka zdań)
# ```
#
# **✅ Czy plik `artykul_llm.txt` jest zapisany na dysku?** Tak / Nie

# %% [markdown]
# ---
# ## 📋 Podsumowanie — czego nauczyłeś się w tym warsztacie?
#
# | # | Umiejętność | ✅ |
# |---|---|---|
# | 1 | Uruchomiłem Ollama i model w terminalu | ☐ |
# | 2 | Wiem, że prompt precyzyjny daje lepsze wyniki | ☐ |
# | 3 | Wiem jak kontrolować format odpowiedzi | ☐ |
# | 4 | Wiem, że LLM może się mylić i trzeba weryfikować | ☐ |
# | 5 | Użyłem modelu z rolą (rekruter) | ☐ |
# | 6 | Mam plik `artykul_llm.txt` gotowy na Warsztat 2 | ☐ |
